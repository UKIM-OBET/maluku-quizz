# %% [markdown]
# # Verifikasi Fitur Quiz
#
# Notebook ini digunakan untuk menguji fitur quiz Laravel dengan menjalankan skrip PHP dan memperbaiki error jika ditemukan.

# %%
import os
import subprocess
from pathlib import Path

workspace = Path(r'c:/Users/user/MALUKUQUIZZ')
assert workspace.exists(), 'Workspace path must exist'

php_path = 'php'

def run_cmd(cmd, cwd=workspace):
    result = subprocess.run(cmd, cwd=cwd, shell=True, capture_output=True, text=True)
    return result.returncode, result.stdout, result.stderr

print('Ready to run commands in', workspace)
